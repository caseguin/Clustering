# %% [markdown]
# ***
# # Cas fictif
#
# ***

# %% [markdown]
# Étapes :
# 1. Analyse exploratoire des données
# 2. Data processing
# 3. Tester les hypothèses
# 4. Analyse statistique
# 5. Recommendations
# 6. Itération et contrôle en continu
# 7. Reporting
# ***

# %%
import os
# get the program file path
cwd = os.getcwd()

# Loop to create folders
folder_names = ['Dataframe', 'Output', 'Data']

folders = {}

for folder_name in folder_names:
    folders[folder_name] = os.path.join(cwd, folder_name)
    
    # print(folders)

    if not os.path.exists(os.path.join(cwd, folder_name)):
        os.makedirs(os.path.join(cwd, folder_name))
        print(f'Le dossier « {folder_name} » a été créé')

    else:
        print(f'Le dossier « {folder_name} » est existant')
# Out:
# Le dossier « Dataframe » est existant
# Le dossier « Output » est existant
# Le dossier « Data » est existant

# %%
# Création des variables de path
path_prog =     cwd + '\\'
path_data =     folders['Data'] + '\\'
path_df =       folders['Dataframe'] + '\\'
path_output =   folders['Output'] + '\\'

# Mettre \\ pour éviter les erreurs
path_dict = [path_prog, path_data, path_df, path_output]
for path in path_dict:
    path = path.replace('\\','\\\\')

# Détermination de l'année
print(path_prog)
print(path_data)
print(path_df)
print(path_output)
# Out:
# c:\Users\Charles_tour\Documents\GitHub\interview_practice\
# c:\Users\Charles_tour\Documents\GitHub\interview_practice\Data\
# c:\Users\Charles_tour\Documents\GitHub\interview_practice\Dataframe\
# c:\Users\Charles_tour\Documents\GitHub\interview_practice\Output\

# %% [markdown]
# ***
# Objectif : Optimiser le prix
# Trouver les liens entre les clients qui dépenses bcp
# Trouver des variables clefs
# Clustering : déterminer des catégorie sur lesquels cibler le marketing
#
#
#
# Option deux : réduire le nombre de Status = Cancelled
# ***

# %%
# Source des données
# https://www.kaggle.com/datasets/thedevastator/unlock-profits-with-e-commerce-sales-data

import pandas as pd

pd.set_option('display.max_columns', None)

sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)
sale_report
# Out:
# C:\Users\Charles_tour\AppData\Local\Temp\ipykernel_10576\964426053.py:8: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)
#                    Order ID      Date                        Status  \
# index
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# index
# 0        Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1        Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3        Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
# ...           ...            ...                ...      ...              ...
# 128970     Amazon      Amazon.in          Expedited  JNE3697    JNE3697-KR-XL
# 128971     Amazon      Amazon.in          Expedited   SET401   SET401-KR-NP-M
# 128972     Amazon      Amazon.in          Expedited    J0157     J0157-DR-XXL
# 128973     Amazon      Amazon.in          Expedited    J0012     J0012-SKD-XS
# 128974     Amazon      Amazon.in          Expedited    J0003      J0003-SET-S
#
#              Category Size        ASIN Courier Status  Qty currency   Amount  \
# index
# 0                 Set    S  B09KXVBD7Z            NaN    0      INR   647.62
# 1               kurta  3XL  B09K3WFS32        Shipped    1      INR   406.00
# 2               kurta   XL  B07WV4JV4D        Shipped    1      INR   329.00
# 3       Western Dress    L  B099NRCT7B            NaN    0      INR   753.33
# 4                 Top  3XL  B098714BZP        Shipped    1      INR   574.00
# ...               ...  ...         ...            ...  ...      ...      ...
# 128970          kurta   XL  B098112V2V        Shipped    1      INR   517.00
# 128971            Set    M  B09VC6KHX8        Shipped    1      INR   999.00
# 128972  Western Dress  XXL  B0982YZ51B        Shipped    1      INR   690.00
# 128973            Set   XS  B0894Y2NJQ        Shipped    1      INR  1199.00
# 128974            Set    S  B0894X27FC        Shipped    1      INR   696.00
#
#           ship-city    ship-state  ship-postal-code ship-country  \
# index
# 0            MUMBAI   MAHARASHTRA          400081.0           IN
# 1         BENGALURU     KARNATAKA          560085.0           IN
# 2       NAVI MUMBAI   MAHARASHTRA          410210.0           IN
# 3        PUDUCHERRY    PUDUCHERRY          605008.0           IN
# 4           CHENNAI    TAMIL NADU          600073.0           IN
# ...             ...           ...               ...          ...
# 128970    HYDERABAD     TELANGANA          500013.0           IN
# 128971     GURUGRAM       HARYANA          122004.0           IN
# 128972    HYDERABAD     TELANGANA          500049.0           IN
# 128973        Halol       Gujarat          389350.0           IN
# 128974       Raipur  CHHATTISGARH          492014.0           IN
#
#                                             promotion-ids    B2B fulfilled-by  \
# index
# 0                                                     NaN  False    Easy Ship
# 1       Amazon PLCC Free-Financing Universal Merchant ...  False    Easy Ship
# 2            IN Core Free Shipping 2015/04/08 23-48-5-108   True          NaN
# 3                                                     NaN  False    Easy Ship
# 4                                                     NaN  False          NaN
# ...                                                   ...    ...          ...
# 128970                                                NaN  False          NaN
# 128971       IN Core Free Shipping 2015/04/08 23-48-5-108  False          NaN
# 128972                                                NaN  False          NaN
# 128973       IN Core Free Shipping 2015/04/08 23-48-5-108  False          NaN
# 128974       IN Core Free Shipping 2015/04/08 23-48-5-108  False          NaN
#
#        Unnamed: 22
# index
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 128970       False
# 128971       False
# 128972       False
# 128973       False
# 128974       False
#
# [128975 rows x 23 columns]

# %% [markdown]
# ***
# # 1. Data cleaning
# ***

# %%
sale_report.isna().sum()
# Out:
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               33
# ship-postal-code         33
# ship-country             33
# promotion-ids         49153
# B2B                       0
# fulfilled-by          89698
# Unnamed: 22           49050
# dtype: int64

# %% [markdown]
# ***
# # 2. Analyse descriptive
# ***

# %%
sale_report.columns.tolist()
# Out:
# ['Order ID',
#  'Date',
#  'Status',
#  'Fulfilment',
#  'Sales Channel ',
#  'ship-service-level',
#  'Style',
#  'SKU',
#  'Category',
#  'Size',
#  'ASIN',
#  'Courier Status',
#  'Qty',
#  'currency',
#  'Amount',
#  'ship-city',
#  'ship-state',
#  'ship-postal-code',
#  'ship-country',
#  'promotion-ids',
#  'B2B',
#  'fulfilled-by',
#  'Unnamed: 22']

# %%
sale_report['Unnamed: 22'].unique()
# Out:
# array([nan, False], dtype=object)

# %%
# Période 
period_start = sale_report['Date'].min()
period_end = sale_report['Date'].max()

print('Date de début des observations : ', period_start)
print('Date de fin des observations : ', period_end)

# Nombre d'observation
print('Nombre d\'observation : ', len(sale_report))
# Out:
# Date de début des observations :  03-31-22
# Date de fin des observations :  06-29-22
# Nombre d'observation :  128975

# %%
# Les variables d'intérêt
col_numer = ['Date', 'Qty', 'Amount', 'ship-postal-code']
col_quali = ['Status', 'Fulfilment', 'Sales Channel ', 'ship-service-level', 'Category', 'Size', 'ship-city', 'ship-state', 'ship-country', 'promotion-ids', 'B2B' ]

# %% [markdown]
# ### Variables quantitatives
# ***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert the 'Date' column to datetime objects
sale_report['Date'] = pd.to_datetime(sale_report['Date'], format='%m-%d-%y')

# Group by date and calculate total amount spent and quantity per date
daily_spending = sale_report.groupby('Date')['Amount'].sum()
daily_quantity = sale_report.groupby('Date')['Qty'].sum()

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

# Plot 1: Amount spent by date
axes[0].plot(daily_spending.index, daily_spending.values, marker='o')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Amount Spent')
axes[0].set_title('Amount Spent by Date')
axes[0].tick_params(axis='x', rotation=45)

# Plot 2: Quantity by date
axes[1].plot(daily_quantity.index, daily_quantity.values, marker='o', color='orange')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Quantity')
axes[1].set_title('Quantity by Date')
axes[1].tick_params(axis='x', rotation=45)

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## **Note** : Le 1er mai c'est la journée du travail en Inde

# %%
import matplotlib.pyplot as plt

sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

sale_report['Date'] = pd.to_datetime(sale_report['Date'], format='%m-%d-%y')

# Plot 1: Distribution of Amount
axes[0].hist(sale_report['Amount'], bins=50, color='blue', alpha=0.7)
axes[0].set_xlabel('Amount Spent')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Distribution of Amount')

# Plot 2: Distribution of Quantity
axes[1].hist(sale_report['Qty'], bins=50, color='orange', alpha=0.7)
axes[1].set_xlabel('Quantity')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Distribution of Quantity')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()
# Out:
# C:\Users\Charles_tour\AppData\Local\Temp\ipykernel_1344\4022066805.py:3: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)

# %%
col_num = ['Amount', 'Qty']
sale_report[col_num].describe()
# Out:
#               Amount            Qty
# count  121180.000000  128975.000000
# mean      648.561465       0.904431
# std       281.211687       0.313354
# min         0.000000       0.000000
# 25%       449.000000       1.000000
# 50%       605.000000       1.000000
# 75%       788.000000       1.000000
# max      5584.000000      15.000000

# %% [markdown]
# ### Variables qualitatives
# ***

# %%
import matplotlib.pyplot as plt

sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)


col_quali = ['Status', 'Fulfilment', 'Sales Channel ', 'ship-service-level', 'Category', 'Size', 'ship-city', 'ship-state', 'ship-country', 'promotion-ids', 'B2B' ]
sale_report[col_quali]
# Out:
# C:\Users\Charles_tour\AppData\Local\Temp\ipykernel_10576\4271445382.py:3: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)
#                               Status Fulfilment Sales Channel   \
# index
# 0                          Cancelled   Merchant      Amazon.in
# 1       Shipped - Delivered to Buyer   Merchant      Amazon.in
# 2                            Shipped     Amazon      Amazon.in
# 3                          Cancelled   Merchant      Amazon.in
# 4                            Shipped     Amazon      Amazon.in
# ...                              ...        ...            ...
# 128970                       Shipped     Amazon      Amazon.in
# 128971                       Shipped     Amazon      Amazon.in
# 128972                       Shipped     Amazon      Amazon.in
# 128973                       Shipped     Amazon      Amazon.in
# 128974                       Shipped     Amazon      Amazon.in
#
#        ship-service-level       Category Size    ship-city    ship-state  \
# index
# 0                Standard            Set    S       MUMBAI   MAHARASHTRA
# 1                Standard          kurta  3XL    BENGALURU     KARNATAKA
# 2               Expedited          kurta   XL  NAVI MUMBAI   MAHARASHTRA
# 3                Standard  Western Dress    L   PUDUCHERRY    PUDUCHERRY
# 4               Expedited            Top  3XL      CHENNAI    TAMIL NADU
# ...                   ...            ...  ...          ...           ...
# 128970          Expedited          kurta   XL    HYDERABAD     TELANGANA
# 128971          Expedited            Set    M     GURUGRAM       HARYANA
# 128972          Expedited  Western Dress  XXL    HYDERABAD     TELANGANA
# 128973          Expedited            Set   XS        Halol       Gujarat
# 128974          Expedited            Set    S       Raipur  CHHATTISGARH
#
#        ship-country                                      promotion-ids    B2B
# index
# 0                IN                                                NaN  False
# 1                IN  Amazon PLCC Free-Financing Universal Merchant ...  False
# 2                IN       IN Core Free Shipping 2015/04/08 23-48-5-108   True
# 3                IN                                                NaN  False
# 4                IN                                                NaN  False
# ...             ...                                                ...    ...
# 128970           IN                                                NaN  False
# 128971           IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 128972           IN                                                NaN  False
# 128973           IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
# 128974           IN       IN Core Free Shipping 2015/04/08 23-48-5-108  False
#
# [128975 rows x 11 columns]

# %%
# Count the number of observations for each city
city_counts = sale_report['ship-city'].value_counts()
state_counts = sale_report['ship-state'].value_counts()

# Keep only the top 11 cities and combine the rest into 'Other'
top_cities = city_counts.head(20).index
top_states = state_counts.head(20).index

sale_report['ship_city_top'] = sale_report['ship-city'].apply(lambda x: x if x in top_cities else 'Other')
sale_report['ship_state_top'] = sale_report['ship-state'].apply(lambda x: x if x in top_states else 'Other')

# %%
print(sale_report['ship_city_top'].value_counts())
# print(sale_report['ship_state_top'].value_counts())
# Out:
# Other            70803
# BENGALURU        11217
# HYDERABAD         8074
# MUMBAI            6126
# NEW DELHI         5795
# CHENNAI           5421
# PUNE              3857
# KOLKATA           2381
# GURUGRAM          1868
# THANE             1701
# LUCKNOW           1458
# NOIDA             1419
# GHAZIABAD         1328
# NAVI MUMBAI       1263
# AHMEDABAD         1236
# JAIPUR             948
# Hyderabad          919
# Mumbai             868
# COIMBATORE         768
# PATNA              764
# VISAKHAPATNAM      761
# Name: ship_city_top, dtype: int64

# %%
# Promotion
import numpy as np
sale_report['promo'] = np.where(sale_report['promotion-ids'].notna(), True, False)
sale_report['ship-country'] = sale_report['ship-country'].fillna('WO')

# %%
sale_report['ship-country'].value_counts()
# Out:
# IN    128942
# WO        33
# Name: ship-country, dtype: int64

# %%
import matplotlib.pyplot as plt
# Count the occurrences of each status
# List of categorical columns
col_quali = ['Status', 'Fulfilment', 'Sales Channel ', 'ship-service-level', 'Category', 'Size', 'ship_city_top', 'ship_state_top', 'ship-country', 'promo', 'B2B']

# Calculate the number of rows and columns for subplots
num_plots = len(col_quali)
num_cols = 2
num_rows = (num_plots + 1) // num_cols

# Create subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(12, 5 * num_rows))

# Flatten the axes array if there's only one row of subplots
if num_rows == 1:
    axes = [axes]

# Create bar plots for each categorical column
for i, column in enumerate(col_quali):
    row = i // num_cols
    col = i % num_cols
    ax = axes[row][col]

    counts = sale_report[column].value_counts()
    ax.bar(counts.index, counts.values, color='purple')
    
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')
    ax.set_title(f'Distribution of {column}')
    ax.tick_params(axis='x', rotation=35)

    ax.set_xticks(range(len(counts)))
    ax.set_xticklabels(counts.index, rotation=35, ha='right')
    
# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ***
# ### Variable d'intérêt après inspection visuel
# ***

# %%
sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)
# Out:
# C:\Users\Charles_tour\AppData\Local\Temp\ipykernel_10576\3668628441.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   sale_report = pd.read_csv(path_data + 'Amazon_Sale_Report.csv', index_col=0)

# %%
sale_report['promo'] = np.where(sale_report['promotion-ids'].notna(), True, False)

col = ['Date', 'Qty', 'Amount', 'Fulfilment', 'ship-service-level', 'Category', 'Size', 'ship-city', 'ship-state', 'promo']
# col = ['Date', 'Amount', 'Fulfilment', 'ship-service-level', 'Category', 'Size', 'ship-city', 'ship-state', 'promo']
sale_report = sale_report[col]
sale_report.head()
# Out:
#            Date  Qty  Amount Fulfilment ship-service-level       Category  \
# index
# 0      04-30-22    0  647.62   Merchant           Standard            Set
# 1      04-30-22    1  406.00   Merchant           Standard          kurta
# 2      04-30-22    1  329.00     Amazon          Expedited          kurta
# 3      04-30-22    0  753.33   Merchant           Standard  Western Dress
# 4      04-30-22    1  574.00     Amazon          Expedited            Top
#
#       Size    ship-city   ship-state  promo
# index
# 0        S       MUMBAI  MAHARASHTRA  False
# 1      3XL    BENGALURU    KARNATAKA   True
# 2       XL  NAVI MUMBAI  MAHARASHTRA   True
# 3        L   PUDUCHERRY   PUDUCHERRY  False
# 4      3XL      CHENNAI   TAMIL NADU  False

# %% [markdown]
# ***
# ### cleaning
# ***

# %%
sale_report.head()
# Out:
#            Date  Qty  Amount Fulfilment ship-service-level       Category  \
# index
# 0      04-30-22    0  647.62   Merchant           Standard            Set
# 1      04-30-22    1  406.00   Merchant           Standard          kurta
# 2      04-30-22    1  329.00     Amazon          Expedited          kurta
# 3      04-30-22    0  753.33   Merchant           Standard  Western Dress
# 4      04-30-22    1  574.00     Amazon          Expedited            Top
#
#       Size    ship-city   ship-state  promo
# index
# 0        S       MUMBAI  MAHARASHTRA  False
# 1      3XL    BENGALURU    KARNATAKA   True
# 2       XL  NAVI MUMBAI  MAHARASHTRA   True
# 3        L   PUDUCHERRY   PUDUCHERRY  False
# 4      3XL      CHENNAI   TAMIL NADU  False

# %%
# Missing values
sale_report.isna().sum()
# Out:
# Date                     0
# Qty                      0
# Amount                7795
# Fulfilment               0
# ship-service-level       0
# Category                 0
# Size                     0
# ship-city               33
# ship-state              33
# promo                    0
# dtype: int64

# %%
print(len(sale_report))
print(len(sale_report.loc[sale_report['Amount'].isna()]))
print(len(sale_report.loc[sale_report['Amount'] == 0]))

print('proportion = na :', len(sale_report.loc[sale_report['Amount'].isna()])/len(sale_report)*100)
print('proportion = 0 :', len(sale_report.loc[sale_report['Amount'] == 0])/len(sale_report)*100)
# Out:
# 128975
# 7795
# 2343
# proportion = na : 6.043806939329328
# proportion = 0 : 1.816631130063966

# %% [markdown]
# La variable d'intérêt est le prix, on va donc éliminer les ligne dont 'Amount' est manquant

# %%
sale_report_na = sale_report.dropna(subset='Amount')

# %%
sale_report_na.describe()
# Out:
#                  Qty         Amount
# count  121180.000000  121180.000000
# mean        0.961231     648.561465
# std         0.214354     281.211687
# min         0.000000       0.000000
# 25%         1.000000     449.000000
# 50%         1.000000     605.000000
# 75%         1.000000     788.000000
# max         8.000000    5584.000000

# %%
sale_report_na.value_counts()
# Out:
# Date      Qty  Amount  Fulfilment  ship-service-level  Category  Size  ship-city     ship-state   promo
# 05-01-22  1    399.0   Amazon      Expedited           kurta     XL    AHMEDABAD     Gujarat      False    7
# 05-03-22  1    399.0   Amazon      Expedited           kurta     S     PUNE          MAHARASHTRA  False    7
# 05-13-22  0    341.9   Merchant    Standard            kurta     L     THANE         MAHARASHTRA  False    6
# 04-03-22  1    481.0   Amazon      Expedited           kurta     XL    BENGALURU     KARNATAKA    True     6
# 05-29-22  1    435.0   Amazon      Expedited           kurta     M     MADIKERI      KARNATAKA    False    5
#                                                                                                           ..
# 04-27-22  1    435.0   Amazon      Expedited           kurta     S     JAJAPUR       ODISHA       True     1
#                                                                  M     puducherry    PUDUCHERRY   False    1
#                                                                        Thane         MAHARASHTRA  False    1
#                                                                        HYDERABAD     TELANGANA    False    1
# 06-29-22  2    1672.0  Merchant    Standard            kurta     4XL   NAGAPATTINAM  TAMIL NADU   True     1
# Length: 117740, dtype: int64

# %%
from scipy.stats import chi2_contingency

# Create a contingency table
contingency_table = pd.crosstab(sale_report_na['promo'], columns='Count')

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Display test results
print(f"Chi-Square: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-Square: 0.0
# P-value: 1.0

# %% [markdown]
# ***
# # Feature engineering
# ***

# %%
sale_report.head()
# Out:
#                   Order ID      Date                        Status Fulfilment  \
# index
# 0      405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1      171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2      404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3      403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4      407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#       Sales Channel  ship-service-level    Style              SKU  \
# index
# 0          Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1          Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2          Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3          Amazon.in           Standard    J0341       J0341-DR-L
# 4          Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#             Category Size        ASIN Courier Status  Qty currency  Amount  \
# index
# 0                Set    S  B09KXVBD7Z            NaN    0      INR  647.62
# 1              kurta  3XL  B09K3WFS32        Shipped    1      INR  406.00
# 2              kurta   XL  B07WV4JV4D        Shipped    1      INR  329.00
# 3      Western Dress    L  B099NRCT7B            NaN    0      INR  753.33
# 4                Top  3XL  B098714BZP        Shipped    1      INR  574.00
#
#          ship-city   ship-state  ship-postal-code ship-country  \
# index
# 0           MUMBAI  MAHARASHTRA          400081.0           IN
# 1        BENGALURU    KARNATAKA          560085.0           IN
# 2      NAVI MUMBAI  MAHARASHTRA          410210.0           IN
# 3       PUDUCHERRY   PUDUCHERRY          605008.0           IN
# 4          CHENNAI   TAMIL NADU          600073.0           IN
#
#                                            promotion-ids    B2B fulfilled-by  \
# index
# 0                                                    NaN  False    Easy Ship
# 1      Amazon PLCC Free-Financing Universal Merchant ...  False    Easy Ship
# 2           IN Core Free Shipping 2015/04/08 23-48-5-108   True          NaN
# 3                                                    NaN  False    Easy Ship
# 4                                                    NaN  False          NaN
#
#       Unnamed: 22
# index
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
# Day of the week
sale_report['Date'] = pd.to_datetime(sale_report['Date'], format='%m-%d-%y')
sale_report['DayOfWeek'] = sale_report['Date'].dt.dayofweek
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
sale_report['DayOfWeekName'] = sale_report['Date'].dt.day_name()

sale_report['DayOfWeekName'].head()
# Out:
# index
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: DayOfWeekName, dtype: object

# %%
sale_report.head(2)
# Out:
#                   Order ID       Date                        Status  \
# index
# 0      405-8078784-5731545 2022-04-30                     Cancelled
# 1      171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
#
#       Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# index
# 0       Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1       Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
#
#       Category Size        ASIN Courier Status  Qty currency  Amount  \
# index
# 0          Set    S  B09KXVBD7Z            NaN    0      INR  647.62
# 1        kurta  3XL  B09K3WFS32        Shipped    1      INR  406.00
#
#        ship-city   ship-state  ship-postal-code ship-country  \
# index
# 0         MUMBAI  MAHARASHTRA          400081.0           IN
# 1      BENGALURU    KARNATAKA          560085.0           IN
#
#                                            promotion-ids    B2B fulfilled-by  \
# index
# 0                                                    NaN  False    Easy Ship
# 1      Amazon PLCC Free-Financing Universal Merchant ...  False    Easy Ship
#
#       Unnamed: 22
# index
# 0             NaN
# 1             NaN

# %%
sale_report['promotion-ids'].unique()
# Out:
# array([nan,
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-XXRCW6NZEPZI4,Amazon PLCC Free-Financing Universal Merchant AAT-CXNSLNBROFDW4,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-WSJLDN3X7KEMO,Amazon PLCC Free-Financing Universal Merchant AAT-VL6FGQVGQVXUS,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-ZYL5UPUNW6T62,Amazon PLCC Free-Financing Universal Merchant AAT-XVPICCHRWDCAI,Amazon PLCC Free-Financing Universal Merchant AAT-ETXQ3XXWMRXBG,Amazon PLCC Free-Financing Universal Merchant AAT-7X3XCTYG64VBE,Amazon PLCC Free-Financing Universal Merchant AAT-7CHGD3WTS3MHM,Amazon PLCC Free-Financing Universal Merchant AAT-26ZDKNME27X42,Amazon PLCC Free-Financing Universal Merchant AAT-4ZF5KN6E4LJK4,Amazon PLCC Free-Financing Universal Merchant AAT-7RCXIKUAX7DDY,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'IN Core Free Shipping 2015/04/08 23-48-5-108', ...,
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-SL3Y2YRMAUNFC,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-EWAPBB6BDRGM6,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-5ZEB2OGNZ32MC,Amazon PLCC Free-Financing Universal Merchant AAT-NT3ZJJGQ3JK3Q,Amazon PLCC Free-Financing Universal Merchant AAT-TNYBHEAO7HOHO,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4,Amazon PLCC Free-Financing Universal Merchant AAT-QMFZ3M7T5NPDS,Amazon PLCC Free-Financing Universal Merchant #MP-pmilan-1601980554292',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-SL3Y2YRMAUNFC,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-EWAPBB6BDRGM6,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-5ZEB2OGNZ32MC,Amazon PLCC Free-Financing Universal Merchant AAT-NT3ZJJGQ3JK3Q,Amazon PLCC Free-Financing Universal Merchant AAT-5SHH3G55USK5C,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4',
#        'Amazon PLCC Free-Financing Universal Merchant AAT-WNKTBO3K27EJC,Amazon PLCC Free-Financing Universal Merchant AAT-QX3UCCJESKPA2,Amazon PLCC Free-Financing Universal Merchant AAT-5QQ7BIYYQEDN2,Amazon PLCC Free-Financing Universal Merchant AAT-DSJ2QRXXWXVMQ,Amazon PLCC Free-Financing Universal Merchant AAT-CXJHMC2YJUK76,Amazon PLCC Free-Financing Universal Merchant AAT-CC4FAVTYR4X7C,Amazon PLCC Free-Financing Universal Merchant AAT-EWAPBB6BDRGM6,Amazon PLCC Free-Financing Universal Merchant AAT-R7GXNZWISTRFA,Amazon PLCC Free-Financing Universal Merchant AAT-EOKPWFWYW7Y6I,Amazon PLCC Free-Financing Universal Merchant AAT-NT3ZJJGQ3JK3Q,Amazon PLCC Free-Financing Universal Merchant AAT-5SHH3G55USK5C,Amazon PLCC Free-Financing Universal Merchant AAT-TNYBHEAO7HOHO,Amazon PLCC Free-Financing Universal Merchant AAT-BRSZZ45H6MHAO,Amazon PLCC Free-Financing Universal Merchant AAT-MKLXOOZWQL7GO,Amazon PLCC Free-Financing Universal Merchant AAT-CB7UNXEXGIJTC,Amazon PLCC Free-Financing Universal Merchant #MP-gzasho-1593152694811,Amazon PLCC Free-Financing Universal Merchant AAT-WLBA4GZ52EAH4,Amazon PLCC Free-Financing Universal Merchant AAT-QMFZ3M7T5NPDS,Amazon PLCC Free-Financing Universal Merchant #MP-pmilan-1601980554292'],
#       dtype=object)

# %%
# sale_report.loc[sale_report['promotion-ids'].duplicated() == True]
# sale_report.loc[sale_report['promotion-ids'] == '403-9615377-8133951']

duplicated_series = sale_report['promotion-ids'].duplicated(keep=False)
duplicated_values = sale_report[duplicated_series]
len(sale_report)
len(duplicated_values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[146], line 4
#       1 # sale_report.loc[sale_report['promotion-ids'].duplicated() == True]
#       2 # sale_report.loc[sale_report['promotion-ids'] == '403-9615377-8133951']
# ----> 4 duplicated_series = sale_report['promotion-ids'].duplicated(keep=True)
#       5 duplicated_values = sale_report[duplicated_series]
#       6 len(sale_report)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:2428, in Series.duplicated(self, keep)
#    2352 def duplicated(self, keep: Literal["first", "last", False] = "first") -> Series:
#    2353     """
#    2354     Indicate duplicate Series values.
#    2355
#    (...)
#    2426     dtype: bool
#    2427     """
# -> 2428     res = self._duplicated(keep=keep)
#    2429     result = self._constructor(res, index=self.index)
#    2430     return result.__finalize__(self, method="duplicated")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\base.py:1314, in IndexOpsMixin._duplicated(self, keep)
#    1310 @final
#    1311 def _duplicated(
#    1312     self, keep: Literal["first", "last", False] = "first"
#    1313 ) -> npt.NDArray[np.bool_]:
# -> 1314     return duplicated(self._values, keep=keep)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\algorithms.py:1063, in duplicated(values, keep)
#    1044 """
#    1045 Return boolean ndarray denoting duplicate values.
#    1046
#    (...)
#    1060 duplicated : ndarray[bool]
#    1061 """
#    1062 values = _ensure_data(values)
# -> 1063 return htable.duplicated(values, keep=keep)
#
# File pandas\_libs\hashtable_func_helper.pxi:2217, in pandas._libs.hashtable.__pyx_fuse_10duplicated()
#
# File pandas\_libs\hashtable_func_helper.pxi:2219, in pandas._libs.hashtable.duplicated()
#
# File pandas\_libs\hashtable_func_helper.pxi:1415, in pandas._libs.hashtable.duplicated_object()
#
# ValueError: keep must be either "first", "last" or False
